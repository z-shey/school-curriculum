# %%
import pandas as pd

# %%
pd.read_excel('result1.xlsx', engine='openpyxl')
# Out:
#        Unnamed: 0  0 s  1 s  2 s  3 s  4 s  5 s  6 s  7 s  8 s  ...  291 s  \
# 0         龙头x (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 1         龙头y (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 2      第1节龙身x (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 3      第1节龙身y (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 4      第2节龙身x (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# ..            ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...    ...
# 443  第221节龙身y (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 444       龙尾x (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 445       龙尾y (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 446    龙尾（后）x (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 447    龙尾（后）y (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
#
#      292 s  293 s  294 s  295 s  296 s  297 s  298 s  299 s  300 s
# ...

# %%
pd.read_excel('result2.xlsx', engine='openpyxl')
# Out:
#     Unnamed: 0  横坐标x (m)  纵坐标y (m)  速度 (m/s)
# 0           龙头       NaN       NaN       NaN
# 1        第1节龙身       NaN       NaN       NaN
# 2        第2节龙身       NaN       NaN       NaN
# 3        第3节龙身       NaN       NaN       NaN
# 4        第4节龙身       NaN       NaN       NaN
# ..         ...       ...       ...       ...
# 219    第219节龙身       NaN       NaN       NaN
# 220    第220节龙身       NaN       NaN       NaN
# 221    第221节龙身       NaN       NaN       NaN
# 222         龙尾       NaN       NaN       NaN
# 223      龙尾（后）       NaN       NaN       NaN
#
# [224 rows x 4 columns]

# %%
pd.read_excel('result4.xlsx', engine='openpyxl')
# Out:
#        Unnamed: 0  -100 s  -99 s  -98 s  -97 s  -96 s  -95 s  -94 s  -93 s  \
# 0         龙头x (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1         龙头y (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2      第1节龙身x (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      第1节龙身y (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      第2节龙身x (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..            ...     ...    ...    ...    ...    ...    ...    ...    ...
# 443  第221节龙身y (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 444       龙尾x (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 445       龙尾y (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 446    龙尾（后）x (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 447    龙尾（后）y (m)     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
result1 = pd.read_excel('result1.xlsx', index_col=0)
result1
# Out:
#               0 s  1 s  2 s  3 s  4 s  5 s  6 s  7 s  8 s  9 s  ...  291 s  \
# 龙头x (m)       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 龙头y (m)       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 第1节龙身x (m)    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 第1节龙身y (m)    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 第2节龙身x (m)    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...    ...
# 第221节龙身y (m)  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 龙尾x (m)       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 龙尾y (m)       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 龙尾（后）x (m)    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 龙尾（后）y (m)    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
#
# ...
